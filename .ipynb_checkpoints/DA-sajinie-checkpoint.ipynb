# %%
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns # data visualization library  
import matplotlib.pyplot as plt
import statsmodels.api as sm
# Out:
# /home/sajinie/anaconda3/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
dengue_features_train = "dengue_features_train.csv"
dengue_labels_train = "dengue_labels_train.csv"

x_train = pd.read_csv(dengue_features_train, index_col=[0])
y_train = pd.read_csv(dengue_labels_train, index_col=[0])

# Seperate data for San Juan
sj_train_features = x_train.loc['sj']
sj_train_labels = y_train.loc['sj']
sj_train_labels = sj_train_labels.drop(['year', 'weekofyear'], axis=1)

# Separate data for Iquitos
iq_train_features = x_train.loc['iq']
iq_train_labels = y_train.loc['iq']
iq_train_labels = iq_train_labels.drop(['year', 'weekofyear'], axis=1)

x_train.head()
# Out:
#       year  weekofyear week_start_date   ndvi_ne   ndvi_nw   ndvi_se  \
# city
# sj    1990          18      1990-04-30  0.122600  0.103725  0.198483
# sj    1990          19      1990-05-07  0.169900  0.142175  0.162357
# sj    1990          20      1990-05-14  0.032250  0.172967  0.157200
# sj    1990          21      1990-05-21  0.128633  0.245067  0.227557
# sj    1990          22      1990-05-28  0.196200  0.262200  0.251200
#
#        ndvi_sw  precipitation_amt_mm  reanalysis_air_temp_k  \
# city
# sj    0.177617                 12.42             297.572857
# sj    0.155486                 22.82             298.211429
# sj    0.170843                 34.54             298.781429
# sj    0.235886                 15.36             298.987143
# sj    0.247340                  7.52             299.518571
#
#       reanalysis_avg_temp_k        ...          \
# city                               ...
# sj               297.742857        ...
# sj               298.442857        ...
# sj               298.878571        ...
# sj               299.228571        ...
# sj               299.664286        ...
#
#       reanalysis_precip_amt_kg_per_m2  reanalysis_relative_humidity_percent  \
# city
# sj                              32.00                             73.365714
# sj                              17.94                             77.368571
# sj                              26.10                             82.052857
# sj                              13.90                             80.337143
# sj                              12.20                             80.460000
#
#       reanalysis_sat_precip_amt_mm  reanalysis_specific_humidity_g_per_kg  \
# city
# sj                           12.42                              14.012857
# sj                           22.82                              15.372857
# sj                           34.54                              16.848571
# sj                           15.36                              16.672857
# sj                            7.52                              17.210000
#
#       reanalysis_tdtr_k  station_avg_temp_c  station_diur_temp_rng_c  \
# city
# sj             2.628571           25.442857                 6.900000
# sj             2.371429           26.714286                 6.371429
# sj             2.300000           26.714286                 6.485714
# sj             2.428571           27.471429                 6.771429
# sj             3.014286           28.942857                 9.371429
#
#       station_max_temp_c  station_min_temp_c  station_precip_mm
# city
# sj                  29.4                20.0               16.0
# sj                  31.7                22.2                8.6
# sj                  32.2                22.8               41.4
# sj                  33.3                23.3                4.0
# sj                  35.0                23.9                5.8
#
# [5 rows x 23 columns]

# %%
output = ['total_cases']
weather_station_measurements =  ['station_max_temp_c', 'station_min_temp_c', 'station_avg_temp_c',
     'station_precip_mm', 'station_diur_temp_rng_c']

satellite_precipitation_measurements = ['precipitation_amt_mm']

climate_forcast_measurements = ['reanalysis_sat_precip_amt_mm', 'reanalysis_dew_point_temp_k', 'reanalysis_air_temp_k', 
                          'reanalysis_relative_humidity_percent', 'reanalysis_specific_humidity_g_per_kg', 
                          'reanalysis_precip_amt_kg_per_m2', 'reanalysis_max_air_temp_k', 'reanalysis_min_air_temp_k', 
                          'reanalysis_avg_temp_k', 'reanalysis_tdtr_k']

ndvi_columns = ['ndvi_se', 'ndvi_sw', 'ndvi_ne', 'ndvi_nw']

#data with all features and total cases for 'sj'. axis = 1 => by column
all_data_for_sj = pd.concat([sj_train_features, sj_train_labels], axis=1)
all_data_for_iq = pd.concat([iq_train_features, iq_train_labels], axis=1)

all_data_for_sj.head()
# Out:
#       year  weekofyear week_start_date   ndvi_ne   ndvi_nw   ndvi_se  \
# city
# sj    1990          18      1990-04-30  0.122600  0.103725  0.198483
# sj    1990          19      1990-05-07  0.169900  0.142175  0.162357
# sj    1990          20      1990-05-14  0.032250  0.172967  0.157200
# sj    1990          21      1990-05-21  0.128633  0.245067  0.227557
# sj    1990          22      1990-05-28  0.196200  0.262200  0.251200
#
#        ndvi_sw  precipitation_amt_mm  reanalysis_air_temp_k  \
# city
# sj    0.177617                 12.42             297.572857
# sj    0.155486                 22.82             298.211429
# sj    0.170843                 34.54             298.781429
# sj    0.235886                 15.36             298.987143
# sj    0.247340                  7.52             299.518571
#
#       reanalysis_avg_temp_k     ...       \
# city                            ...
# sj               297.742857     ...
# sj               298.442857     ...
# sj               298.878571     ...
# sj               299.228571     ...
# sj               299.664286     ...
#
#       reanalysis_relative_humidity_percent  reanalysis_sat_precip_amt_mm  \
# city
# sj                               73.365714                         12.42
# sj                               77.368571                         22.82
# sj                               82.052857                         34.54
# sj                               80.337143                         15.36
# sj                               80.460000                          7.52
#
#       reanalysis_specific_humidity_g_per_kg  reanalysis_tdtr_k  \
# city
# sj                                14.012857           2.628571
# sj                                15.372857           2.371429
# sj                                16.848571           2.300000
# sj                                16.672857           2.428571
# sj                                17.210000           3.014286
#
#       station_avg_temp_c  station_diur_temp_rng_c  station_max_temp_c  \
# city
# sj             25.442857                 6.900000                29.4
# sj             26.714286                 6.371429                31.7
# sj             26.714286                 6.485714                32.2
# sj             27.471429                 6.771429                33.3
# sj             28.942857                 9.371429                35.0
#
#       station_min_temp_c  station_precip_mm  total_cases
# city
# sj                  20.0               16.0            4
# sj                  22.2                8.6            5
# sj                  22.8               41.4            4
# sj                  23.3                4.0            3
# sj                  23.9                5.8            6
#
# [5 rows x 24 columns]

# %%
from sklearn.preprocessing import Imputer

def fillMissingValues(x):

    # Drop irrelevant columns
    x = x.drop(['week_start_date'], axis=1)

    # Processing categoricals
    #One hot encoding categoricals
    x = pd.get_dummies(x)

    #without categoricals
    x = x.select_dtypes(exclude=['object'])
    
    x.fillna(method='ffill', inplace=True)

    return x

# %%
all_data = pd.concat([all_data_for_sj, all_data_for_iq], axis=0)
all_data.head(8)
# Out:
#       year  weekofyear week_start_date   ndvi_ne   ndvi_nw   ndvi_se  \
# city
# sj    1990          18      1990-04-30  0.122600  0.103725  0.198483
# sj    1990          19      1990-05-07  0.169900  0.142175  0.162357
# sj    1990          20      1990-05-14  0.032250  0.172967  0.157200
# sj    1990          21      1990-05-21  0.128633  0.245067  0.227557
# sj    1990          22      1990-05-28  0.196200  0.262200  0.251200
# sj    1990          23      1990-06-04       NaN  0.174850  0.254314
# sj    1990          24      1990-06-11  0.112900  0.092800  0.205071
# sj    1990          25      1990-06-18  0.072500  0.072500  0.151471
#
#        ndvi_sw  precipitation_amt_mm  reanalysis_air_temp_k  \
# city
# sj    0.177617                 12.42             297.572857
# sj    0.155486                 22.82             298.211429
# sj    0.170843                 34.54             298.781429
# sj    0.235886                 15.36             298.987143
# sj    0.247340                  7.52             299.518571
# sj    0.181743                  9.58             299.630000
# sj    0.210271                  3.48             299.207143
# sj    0.133029                151.12             299.591429
#
#       reanalysis_avg_temp_k     ...       \
# city                            ...
# sj               297.742857     ...
# sj               298.442857     ...
# sj               298.878571     ...
# sj               299.228571     ...
# sj               299.664286     ...
# sj               299.764286     ...
# sj               299.221429     ...
# sj               299.528571     ...
#
#       reanalysis_relative_humidity_percent  reanalysis_sat_precip_amt_mm  \
# city
# sj                               73.365714                         12.42
# sj                               77.368571                         22.82
# sj                               82.052857                         34.54
# sj                               80.337143                         15.36
# sj                               80.460000                          7.52
# sj                               79.891429                          9.58
# sj                               82.000000                          3.48
# sj                               83.375714                        151.12
#
#       reanalysis_specific_humidity_g_per_kg  reanalysis_tdtr_k  \
# city
# sj                                14.012857           2.628571
# sj                                15.372857           2.371429
# sj                                16.848571           2.300000
# sj                                16.672857           2.428571
# sj                                17.210000           3.014286
# sj                                17.212857           2.100000
# sj                                17.234286           2.042857
# sj                                17.977143           1.571429
#
#       station_avg_temp_c  station_diur_temp_rng_c  station_max_temp_c  \
# city
# sj             25.442857                 6.900000                29.4
# sj             26.714286                 6.371429                31.7
# sj             26.714286                 6.485714                32.2
# sj             27.471429                 6.771429                33.3
# sj             28.942857                 9.371429                35.0
# sj             28.114286                 6.942857                34.4
# sj             27.414286                 6.771429                32.2
# sj             28.371429                 7.685714                33.9
#
#       station_min_temp_c  station_precip_mm  total_cases
# city
# sj                  20.0               16.0            4
# sj                  22.2                8.6            5
# sj                  22.8               41.4            4
# sj                  23.3                4.0            3
# sj                  23.9                5.8            6
# sj                  23.9               39.1            2
# sj                  23.3               29.7            4
# sj                  22.8               21.1            5
#
# [8 rows x 24 columns]

# %%
formatted_all_data = fillMissingValues(all_data)
formatted_all_data.head(8)

c = formatted_all_data['total_cases']
c.head()

#total_cases_excluded_formatted_data = formatted_all_data.drop(['total_cases'], axis=1)
#total_cases_excluded_formatted_data.head(8)
# Out:
# city
# sj    4
# sj    5
# sj    4
# sj    3
# sj    6
# Name: total_cases, dtype: int64

# %%
from sklearn.preprocessing import MinMaxScaler
import numpy as np

def rescaleData(y):
    x = pd.get_dummies(y)
    x = x.drop(['total_cases'], axis=1)
    array = x.values
    # separate array into input and output components
    X = array[:,0:21]
    scaler = MinMaxScaler(feature_range=(0, 1))
    rescaledX = scaler.fit_transform(X)
    
    # summarize transformed data
    np.set_printoptions(precision=3)
    print(rescaledX[0:5,:])
    
def rescaleDataNew(x):
    x = x.drop(['total_cases'], axis=1)
    # separate array into input and output components
    
    scaler = MinMaxScaler(feature_range=(0, 1))
    x[ndvi_columns + satellite_precipitation_measurements + weather_station_measurements + climate_forcast_measurements] = scaler.fit_transform(x[ndvi_columns + satellite_precipitation_measurements + weather_station_measurements + climate_forcast_measurements])
    
#     x = scaler.fit_transform(x)
    # summarize transformed data
    np.set_printoptions(precision=3)
    return x
    
    
x = rescaleDataNew(formatted_all_data)
# print(x[0:5,:])
x.head()
# Out:
#       year  weekofyear   ndvi_ne   ndvi_nw   ndvi_se   ndvi_sw  \
# city
# sj    1990          18  0.578226  0.614835  0.386418  0.395544
# sj    1990          19  0.629943  0.657063  0.321190  0.359233
# sj    1990          20  0.479441  0.690881  0.311879  0.384430
# sj    1990          21  0.584823  0.770066  0.438912  0.491150
# sj    1990          22  0.658698  0.788882  0.481601  0.509943
#
#       precipitation_amt_mm  reanalysis_air_temp_k  reanalysis_avg_temp_k  \
# city
# sj                0.031797               0.388291               0.354667
# sj                0.058423               0.472710               0.441778
# sj                0.088428               0.548064               0.496000
# sj                0.039324               0.575260               0.539556
# sj                0.019252               0.645515               0.593778
#
#       reanalysis_dew_point_temp_k        ...          \
# city                                     ...
# sj                       0.314680        ...
# sj                       0.489213        ...
# sj                       0.657583        ...
# sj                       0.643471        ...
# sj                       0.701541        ...
#
#       reanalysis_precip_amt_kg_per_m2  reanalysis_relative_humidity_percent  \
# city
# sj                           0.056091                              0.381614
# sj                           0.031446                              0.479668
# sj                           0.045749                              0.594415
# sj                           0.024365                              0.552387
# sj                           0.021385                              0.555396
#
#       reanalysis_sat_precip_amt_mm  reanalysis_specific_humidity_g_per_kg  \
# city
# sj                        0.031797                               0.262659
# sj                        0.058423                               0.418164
# sj                        0.088428                               0.586900
# sj                        0.039324                               0.566808
# sj                        0.019252                               0.628226
#
#       reanalysis_tdtr_k  station_avg_temp_c  station_diur_temp_rng_c  \
# city
# sj             0.086660            0.430091                 0.210393
# sj             0.069133            0.565350                 0.163498
# sj             0.064265            0.565350                 0.173638
# sj             0.073028            0.645897                 0.198986
# sj             0.112950            0.802432                 0.429658
#
#       station_max_temp_c  station_min_temp_c  station_precip_mm
# city
# sj              0.174194            0.486239           0.029450
# sj              0.322581            0.688073           0.015829
# sj              0.354839            0.743119           0.076201
# sj              0.425806            0.788991           0.007362
# sj              0.535484            0.844037           0.010676
#
# [5 rows x 22 columns]

# %%
from sklearn.preprocessing import StandardScaler

def standardizeData(Y):
    X = pd.get_dummies(Y)
    X = X.drop(['total_cases'], axis=1)
    scaler = StandardScaler().fit(X[ndvi_columns + satellite_precipitation_measurements + weather_station_measurements + climate_forcast_measurements])
    X[ndvi_columns + satellite_precipitation_measurements + weather_station_measurements + climate_forcast_measurements] = scaler.transform(X[ndvi_columns + satellite_precipitation_measurements + weather_station_measurements + climate_forcast_measurements])
    # summarize transformed data
    np.set_printoptions(precision=3)
    return X

x = standardizeData(formatted_all_data)
# print(x[0:5,:])
x.head()
# Out:
#       year  weekofyear   ndvi_ne   ndvi_nw   ndvi_se   ndvi_sw  \
# city
# sj    1990          18 -0.062619 -0.203670 -0.055424 -0.291644
# sj    1990          19  0.278949  0.118034 -0.541096 -0.556484
# sj    1990          20 -0.715063  0.375662 -0.610427 -0.372705
# sj    1990          21 -0.019050  0.978910  0.335437  0.405659
# sj    1990          22  0.468869  1.122261  0.653287  0.542732
#
#       precipitation_amt_mm  reanalysis_air_temp_k  reanalysis_avg_temp_k  \
# city
# sj               -0.760139              -0.826384              -1.171427
# sj               -0.522502              -0.357358              -0.616859
# sj               -0.254704               0.061303              -0.271668
# sj               -0.692961               0.212399               0.005616
# sj               -0.872102               0.602730               0.350807
#
#       reanalysis_dew_point_temp_k        ...          \
# city                                     ...
# sj                      -1.854064        ...
# sj                      -0.847423        ...
# sj                       0.123667        ...
# sj                       0.042275        ...
# sj                       0.377199        ...
#
#       reanalysis_precip_amt_kg_per_m2  reanalysis_relative_humidity_percent  \
# city
# sj                          -0.187274                             -1.230763
# sj                          -0.511878                             -0.671592
# sj                          -0.323488                             -0.017231
# sj                          -0.605150                             -0.256904
# sj                          -0.644398                             -0.239741
#
#       reanalysis_sat_precip_amt_mm  reanalysis_specific_humidity_g_per_kg  \
# city
# sj                       -0.760139                              -1.772476
# sj                       -0.522502                              -0.890359
# sj                       -0.254704                               0.066811
# sj                       -0.692961                              -0.047160
# sj                       -0.872102                               0.301239
#
#       reanalysis_tdtr_k  station_avg_temp_c  station_diur_temp_rng_c  \
# city
# sj            -0.641063           -1.356941                -0.558712
# sj            -0.713680           -0.363964                -0.807790
# sj            -0.733851           -0.363964                -0.753935
# sj            -0.697543            0.227360                -0.619298
# sj            -0.532139            1.376536                 0.605899
#
#       station_max_temp_c  station_min_temp_c  station_precip_mm
# city
# sj             -1.552648           -1.338708          -0.489876
# sj             -0.379236            0.063840          -0.646168
# sj             -0.124146            0.446353           0.046589
# sj              0.437051            0.765113          -0.743323
# sj              1.304356            1.147626          -0.705306
#
# [5 rows x 22 columns]

# %%
from sklearn.preprocessing import Normalizer

def normalizeData(y):
    x = pd.get_dummies(y)
    x = x.drop(['total_cases'], axis=1)
    scaler = Normalizer().fit(x)
    x[ndvi_columns + satellite_precipitation_measurements + weather_station_measurements + climate_forcast_measurements] = scaler.transform(x[ndvi_columns + satellite_precipitation_measurements + weather_station_measurements + climate_forcast_measurements])
    
    return x

# ndvi_columns + satellite_precipitation_measurements + weather_station_measurements + climate_forcast_measurements


def n(x):
    x = x.drop(['total_cases','year','weekofyear'], axis=1)
    array = x.values
    # separate array into input and output components
    X = array[:,0:21]
    scaler = Normalizer().fit(X)
    normalizedX = scaler.transform(X)
    # summarize transformed data
    np.set_printoptions(precision=3)
    print(normalizedX[0:5,:])



x = normalizeData(formatted_all_data)
x.head()
# print(x[0:5,:])

# n(formatted_all_data)
# Out:
#       year  weekofyear   ndvi_ne   ndvi_nw   ndvi_se   ndvi_sw  \
# city
# sj    1990          18  0.000183  0.000155  0.000296  0.000265
# sj    1990          19  0.000253  0.000211  0.000241  0.000231
# sj    1990          20  0.000048  0.000255  0.000232  0.000252
# sj    1990          21  0.000191  0.000363  0.000337  0.000350
# sj    1990          22  0.000290  0.000388  0.000372  0.000366
#
#       precipitation_amt_mm  reanalysis_air_temp_k  reanalysis_avg_temp_k  \
# city
# sj                0.018530               0.443952               0.444206
# sj                0.033916               0.443212               0.443555
# sj                0.050999               0.441161               0.441305
# sj                0.022770               0.443218               0.443576
# sj                0.011130               0.443322               0.443538
#
#       reanalysis_dew_point_temp_k        ...          \
# city                                     ...
# sj                       0.436256        ...
# sj                       0.436880        ...
# sj                       0.436219        ...
# sj                       0.437767        ...
# sj                       0.437850        ...
#
#       reanalysis_precip_amt_kg_per_m2  reanalysis_relative_humidity_percent  \
# city
# sj                           0.047741                              0.109455
# sj                           0.026663                              0.114988
# sj                           0.038538                              0.121154
# sj                           0.020605                              0.119092
# sj                           0.018057                              0.119090
#
#       reanalysis_sat_precip_amt_mm  reanalysis_specific_humidity_g_per_kg  \
# city
# sj                        0.018530                               0.020906
# sj                        0.033916                               0.022848
# sj                        0.050999                               0.024877
# sj                        0.022770                               0.024716
# sj                        0.011130                               0.025473
#
#       reanalysis_tdtr_k  station_avg_temp_c  station_diur_temp_rng_c  \
# city
# sj             0.003922            0.037958                 0.010294
# sj             0.003524            0.039704                 0.009469
# sj             0.003396            0.039445                 0.009576
# sj             0.003600            0.040724                 0.010038
# sj             0.004461            0.042839                 0.013871
#
#       station_max_temp_c  station_min_temp_c  station_precip_mm
# city
# sj              0.043862            0.029838           0.023871
# sj              0.047114            0.032994           0.012782
# sj              0.047544            0.033665           0.061129
# sj              0.049364            0.034540           0.005930
# sj              0.051804            0.035375           0.008585
#
# [5 rows x 22 columns]

# %%
n(formatted_all_data)
# Out:
# [[-0.014 -0.046 -0.012 -0.066 -0.171 -0.186 -0.264 -0.417 -0.252  0.016
#   -0.042 -0.277 -0.171 -0.399 -0.144 -0.305 -0.126 -0.349 -0.301 -0.11 ]
#  [ 0.109  0.046 -0.212 -0.218 -0.205 -0.14  -0.242 -0.332 -0.306  0.104
#   -0.201 -0.263 -0.205 -0.349 -0.28  -0.143 -0.317 -0.149  0.025 -0.253]
#  [-0.351  0.184 -0.3   -0.183 -0.125  0.03  -0.133  0.061 -0.443  0.303
#   -0.159 -0.008 -0.125  0.033 -0.36  -0.179 -0.37  -0.061  0.219  0.023]
#  [-0.008  0.415  0.142  0.172 -0.294  0.09   0.002  0.018 -0.265  0.212
#   -0.256 -0.109 -0.294 -0.02  -0.296  0.096 -0.262  0.185  0.324 -0.315]
#  [ 0.137  0.328  0.191  0.159 -0.255  0.176  0.103  0.11  -0.138  0.204
#   -0.189 -0.07  -0.255  0.088 -0.156  0.403  0.177  0.382  0.336 -0.206]]

# %%
# i= x.iloc[-1:]
j= formatted_all_data.precipitation_amt_mm
print (j)
# j = j[:-1]
# col = []
# for k in i.precipitation_amt_mm:
#     col.append(k)
# for k in j:
#     col.append(k)
# x['pre_precipitation_amt_mm'] = col
# Out:
# city
# sj   -0.171089
# sj   -0.204776
# sj   -0.125033
# sj   -0.293642
# sj   -0.255179
# sj   -0.289792
# sj   -0.426197
# sj    0.543926
# sj   -0.219204
# sj   -0.208492
# sj   -0.249331
# sj    0.098057
# sj   -0.303692
# sj   -0.073028
# sj   -0.125123
# sj    0.304603
# sj   -0.101888
# sj   -0.026887
# sj   -0.124991
# sj    0.092110
# sj    0.504364
# sj    0.038729
# sj   -0.093964
# sj    0.034523
# sj    0.330851
# sj    0.484163
# sj    0.341084
# sj   -0.191926
# sj   -0.192861
# sj   -0.196721
#         ...
# iq    0.108723
# iq    0.215701
# iq    0.146614
# iq    0.321884
# iq    0.321884
# iq   -0.100676
# iq   -0.070445
# iq   -0.149753
# iq    0.393710
# iq    0.010972
# iq    0.155966
# iq   -0.067813
# iq    0.116867
# iq    0.154768
# iq    0.048912
# iq    0.231787
# iq    0.021477
# iq    0.022352
# iq    0.178419
# iq   -0.156811
# iq    0.209571
# iq   -0.097969
# iq    0.157775
# iq    0.081383
# iq   -0.202060
# iq    0.044397
# iq    0.173827
# iq    0.067668
# iq    0.069117
# iq    0.103623
# Name: precipitation_amt_mm, Length: 1456, dtype: float64
